# %%
import torch 
import numpy as np
from torch import nn
import matplotlib.pyplot as plt
from torchvision import datasets, transforms 
from torch.utils.data import DataLoader, random_split
from torch.utils.data.sampler import SubsetRandomSampler

# %%
class CostumeDataset:
    def __init__(self, path, h, w):
        self.h = h
        self.w = w
        self.path = path 
        self.data = None
    
    def make_dataset(self):
        normalize = transforms.Normalize(mean=[0.5, 0.5, 0.5], 
                                         std=[0.2, 0.2, 0.2])
        
        self.data = datasets.ImageFolder(self.path, transforms.Compose([
            transforms.Resize((self.h, self.w)), 
            # transforms.CenterCrop(224), 
            transforms.ToTensor(), 
            normalize,]))
        
        # self.class_to_idx = self.data.class_to_idx 
        # self.idx_to_class = {v: int(k) for k,v in self.class_to_idx.items()
        
        return self.data
    
    def get_data_loader(self, batch_size, num_workers=0,):
        
        if self.data is None:
            self.make_dataset()
            
        n_data = len(self.data.samples)
        indices = np.arange(n_data)
        np.random.shuffle(indices)
        sampler = SubsetRandomSampler(indices)
        data_loader = DataLoader(self.data, 
                                 batch_size=batch_size, 
                                 shuffle=False, 
                                 num_workers=num_workers,
                                 sampler=sampler)
        return data_loader

# %%
batch_size = 64
h, w = 224, 224  # to be compatible with VGG image size

# %% [markdown]
# # Load datasets

# %%
train_data = CostumeDataset(path="../data/flower_photos/train/", h=h, w=w)
train_dataloader_f = train_data.get_data_loader(batch_size=batch_size, num_workers=0, )

train_dataloader_f.dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3130
#     Root location: ../data/flower_photos/train/
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                Normalize(mean=[0.5, 0.5, 0.5], std=[0.2, 0.2, 0.2])
#            )

# %%
train_size = int(0.9 * len(train_dataloader_f))
val_size = len(train_dataloader_f) - train_size
train_size, val_size 
train_dataloader, val_dataloader= torch.utils.data.random_split(train_dataloader_f, 
                                                                [train_size, val_size])

# %%
test_data = CostumeDataset(path="../data/flower_photos/test/", h=h, w=w)
test_dataloader = test_data.get_data_loader(batch_size=batch_size, num_workers=0, )

test_dataloader.dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 540
#     Root location: ../data/flower_photos/test/
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                Normalize(mean=[0.5, 0.5, 0.5], std=[0.2, 0.2, 0.2])
#            )

# %%
train_features, train_labels = next(iter(test_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()[0]
label = train_labels[0]
# Out:
# Feature batch shape: torch.Size([64, 3, 224, 224])
# Labels batch shape: torch.Size([64])

# %%
plt.figure(figsize=(10.5, 6.5))
plt.imshow(img, )
plt.show()
print(f"Label: {label}")
# Out:
# Label: 2

# %%
train_data.data.class_to_idx
# Out:
# {'daisy': 0, 'dandelion': 1, 'roses': 2, 'sunflowers': 3, 'tulips': 4}

# %%
n_classes = len(train_data.data.class_to_idx.keys())
n_classes
# Out:
# 5

# %%
for batch, (x, y) in enumerate(train_dataloader.dataset):
    print(batch)
    print("X.shape:", x.shape)
    print("y.shape:", y.shape)
    break
# Out:
# 0
# X.shape: torch.Size([64, 3, 224, 224])
# y.shape: torch.Size([64])

# %%
for batch, (x, y) in enumerate(test_dataloader):
    print(batch)
    print("X.shape:", x.shape)
    print("y.shape:", y.shape)
    break
# Out:
# 0
# X.shape: torch.Size([64, 3, 224, 224])
# y.shape: torch.Size([64])

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# ## Vanilla Neural Network

# %%
class VNN(nn.Module):
    def __init__(self, n_inputs, n_outputs, n_classes):
        super(VNN, self).__init__()
        self.n_inputs = n_inputs
        self.n_outputs = n_outputs
        self.n_classes = n_classes
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(in_features=self.n_inputs, out_features=n_outputs, ),
            nn.ReLU(),
            nn.Linear(in_features=n_outputs, out_features=n_outputs), 
            nn.ReLU(), 
            nn.Linear(in_features=n_outputs, out_features=n_classes))
        
    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
model_vnn = VNN(n_inputs=3*h*w, n_outputs=256, n_classes=5).to(device)
print(model_vnn)
# Out:
# VNN(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=150528, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=5, bias=True)
#   )
# )

# %%
lr = 1e-4
n_epochs = 150  # I am facing computational resource limits

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_vnn.parameters(), lr=lr,)

# %%
def train(data_loader, model, loss_fn, optimizer,):
    size = len(data_loader) * batch_size
    model.train()
    
    for batch, (x, y) in enumerate(data_loader.dataset):
        x, y = x.to(device), y.to(device)
        
        # Compute prediction error
        pred = model(x)
        loss = loss_fn(pred, y)
        
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if batch % 10 == 0:
            loss, current = loss.item(), batch * len(x)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
        
    return loss

# %%
def test (data_loader, model, loss_fn, ):
    size = len(data_loader.dataset)
    num_batch = len(data_loader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for x, y in data_loader:
            x, y = x.to(device), y.to(device)
            pred = model(x)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item() 
        test_loss /= num_batch
        correct /= size 
        print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return test_loss

# %%
train_loss, val_loss = [], []
for t in range(n_epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    t_loss = train(train_dataloader, model_vnn, loss_fn, optimizer)
    v_loss = test(val_dataloader.dataset, model_vnn, loss_fn)
    train_loss.append(t_loss)
    val_loss.append(v_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.600748  [    0/ 2816]
# loss: 2.079618  [  640/ 2816]
# loss: 1.150915  [ 1280/ 2816]
# loss: 1.393766  [ 1920/ 2816]
# loss: 2.222114  [ 2560/ 2816]
# Test Error:
#  Accuracy: 59.3%, Avg loss: 1.136404
#
# Epoch 2
# -------------------------------
# loss: 1.148418  [    0/ 2816]
# loss: 1.301668  [  640/ 2816]
# loss: 1.382223  [ 1280/ 2816]
# loss: 1.295773  [ 1920/ 2816]
# loss: 1.215292  [ 2560/ 2816]
# Test Error:
#  Accuracy: 65.9%, Avg loss: 0.962233
#
# Epoch 3
# -------------------------------
# loss: 0.908660  [    0/ 2816]
# loss: 0.781400  [  640/ 2816]
# loss: 0.629538  [ 1280/ 2816]
# loss: 0.724860  [ 1920/ 2816]
# loss: 1.070565  [ 2560/ 2816]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.630120
#
# Epoch 4
# -------------------------------
# loss: 0.566294  [    0/ 2816]
# loss: 0.658242  [  640/ 2816]
# loss: 0.697437  [ 1280/ 2816]
# loss: 0.510167  [ 1920/ 2816]
# loss: 0.550819  [ 2560/ 2816]
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.508809
#
# Epoch 5
# -------------------------------
# loss: 0.562570  [    0/ 2816]
# loss: 0.574016  [  640/ 2816]
# loss: 0.681028  [ 1280/ 2816]
# loss: 0.471501  [ 1920/ 2816]
# loss: 0.394224  [ 2560/ 2816]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.421235
#
# Epoch 6
# -------------------------------
# loss: 0.292073  [    0/ 2816]
# loss: 0.335709  [  640/ 2816]
# loss: 0.597609  [ 1280/ 2816]
# loss: 0.519041  [ 1920/ 2816]
# loss: 0.579729  [ 2560/ 2816]
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.285409
#
# Epoch 7
# -------------------------------
# loss: 0.263538  [    0/ 2816]
# loss: 0.218690  [  640/ 2816]
# loss: 0.342345  [ 1280/ 2816]
# loss: 0.379737  [ 1920/ 2816]
# loss: 0.364409  [ 2560/ 2816]
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.230301
#
# Epoch 8
# -------------------------------
# loss: 0.214853  [    0/ 2816]
# loss: 0.220644  [  640/ 2816]
# loss: 0.392043  [ 1280/ 2816]
# loss: 0.377264  [ 1920/ 2816]
# loss: 0.209675  [ 2560/ 2816]
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.180530
#
# Epoch 9
# -------------------------------
# loss: 0.185922  [    0/ 2816]
# loss: 0.252144  [  640/ 2816]
# loss: 0.092989  [ 1280/ 2816]
# loss: 0.163683  [ 1920/ 2816]
# loss: 0.187476  [ 2560/ 2816]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.134176
#
# Epoch 10
# -------------------------------
# loss: 0.180319  [    0/ 2816]
# loss: 0.110729  [  640/ 2816]
# loss: 0.194145  [ 1280/ 2816]
# loss: 0.236676  [ 1920/ 2816]
# loss: 0.160437  [ 2560/ 2816]
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.158893
#
# Epoch 11
# -------------------------------
# loss: 0.141666  [    0/ 2816]
# loss: 0.139025  [  640/ 2816]
# loss: 0.152465  [ 1280/ 2816]
# loss: 0.150034  [ 1920/ 2816]
# loss: 0.105207  [ 2560/ 2816]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.107625
#
# Epoch 12
# -------------------------------
# loss: 0.097731  [    0/ 2816]
# loss: 0.075400  [  640/ 2816]
# loss: 0.080510  [ 1280/ 2816]
# loss: 0.157586  [ 1920/ 2816]
# loss: 0.102310  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.108660
#
# Epoch 13
# -------------------------------
# loss: 0.263601  [    0/ 2816]
# loss: 0.076405  [  640/ 2816]
# loss: 0.047665  [ 1280/ 2816]
# loss: 0.051915  [ 1920/ 2816]
# loss: 0.072876  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.076362
#
# Epoch 14
# -------------------------------
# loss: 0.095046  [    0/ 2816]
# loss: 0.050607  [  640/ 2816]
# loss: 0.196310  [ 1280/ 2816]
# loss: 0.121598  [ 1920/ 2816]
# loss: 0.068634  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.069641
#
# Epoch 15
# -------------------------------
# loss: 0.026994  [    0/ 2816]
# loss: 0.066141  [  640/ 2816]
# loss: 0.072095  [ 1280/ 2816]
# loss: 0.109641  [ 1920/ 2816]
# loss: 0.199857  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.091915
#
# Epoch 16
# -------------------------------
# loss: 0.067677  [    0/ 2816]
# loss: 0.083979  [  640/ 2816]
# loss: 0.154488  [ 1280/ 2816]
# loss: 0.063023  [ 1920/ 2816]
# loss: 0.238623  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.9%, Avg loss: 0.076942
#
# Epoch 17
# -------------------------------
# loss: 0.033346  [    0/ 2816]
# loss: 0.045797  [  640/ 2816]
# loss: 0.034793  [ 1280/ 2816]
# loss: 0.227870  [ 1920/ 2816]
# loss: 0.033536  [ 2560/ 2816]
# Test Error:
#  Accuracy: 97.7%, Avg loss: 0.075115
#
# Epoch 18
# -------------------------------
# loss: 0.075711  [    0/ 2816]
# loss: 0.032892  [  640/ 2816]
# loss: 0.049092  [ 1280/ 2816]
# loss: 0.014640  [ 1920/ 2816]
# loss: 0.073717  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.036538
#
# Epoch 19
# -------------------------------
# loss: 0.014838  [    0/ 2816]
# loss: 0.029146  [  640/ 2816]
# loss: 0.076699  [ 1280/ 2816]
# loss: 0.036872  [ 1920/ 2816]
# loss: 0.064683  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.053752
#
# Epoch 20
# -------------------------------
# loss: 0.034449  [    0/ 2816]
# loss: 0.023990  [  640/ 2816]
# loss: 0.038386  [ 1280/ 2816]
# loss: 0.054256  [ 1920/ 2816]
# loss: 0.193193  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.043798
#
# Epoch 21
# -------------------------------
# loss: 0.015093  [    0/ 2816]
# loss: 0.101853  [  640/ 2816]
# loss: 0.207737  [ 1280/ 2816]
# loss: 0.022569  [ 1920/ 2816]
# loss: 0.036972  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.066186
#
# Epoch 22
# -------------------------------
# loss: 0.091831  [    0/ 2816]
# loss: 0.029424  [  640/ 2816]
# loss: 0.028004  [ 1280/ 2816]
# loss: 0.027454  [ 1920/ 2816]
# loss: 0.033405  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.032114
#
# Epoch 23
# -------------------------------
# loss: 0.018690  [    0/ 2816]
# loss: 0.052735  [  640/ 2816]
# loss: 0.026978  [ 1280/ 2816]
# loss: 0.013188  [ 1920/ 2816]
# loss: 0.014258  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.018067
#
# Epoch 24
# -------------------------------
# loss: 0.023751  [    0/ 2816]
# loss: 0.008989  [  640/ 2816]
# loss: 0.007898  [ 1280/ 2816]
# loss: 0.078190  [ 1920/ 2816]
# loss: 0.029383  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.021320
#
# Epoch 25
# -------------------------------
# loss: 0.007561  [    0/ 2816]
# loss: 0.006586  [  640/ 2816]
# loss: 0.060613  [ 1280/ 2816]
# loss: 0.032066  [ 1920/ 2816]
# loss: 0.037311  [ 2560/ 2816]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.123679
#
# Epoch 26
# -------------------------------
# loss: 0.073352  [    0/ 2816]
# loss: 0.135226  [  640/ 2816]
# loss: 0.075320  [ 1280/ 2816]
# loss: 0.069738  [ 1920/ 2816]
# loss: 0.063309  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.057996
#
# Epoch 27
# -------------------------------
# loss: 0.018365  [    0/ 2816]
# loss: 0.119929  [  640/ 2816]
# loss: 0.069293  [ 1280/ 2816]
# loss: 0.026404  [ 1920/ 2816]
# loss: 0.045544  [ 2560/ 2816]
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.102907
#
# Epoch 28
# -------------------------------
# loss: 0.057842  [    0/ 2816]
# loss: 0.021071  [  640/ 2816]
# loss: 0.080057  [ 1280/ 2816]
# loss: 0.195942  [ 1920/ 2816]
# loss: 0.055196  [ 2560/ 2816]
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.078022
#
# Epoch 29
# -------------------------------
# loss: 0.075418  [    0/ 2816]
# loss: 0.036198  [  640/ 2816]
# loss: 0.224169  [ 1280/ 2816]
# loss: 0.090589  [ 1920/ 2816]
# loss: 0.187940  [ 2560/ 2816]
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.194322
#
# Epoch 30
# -------------------------------
# loss: 0.112689  [    0/ 2816]
# loss: 0.049202  [  640/ 2816]
# loss: 0.036254  [ 1280/ 2816]
# loss: 0.138313  [ 1920/ 2816]
# loss: 0.276055  [ 2560/ 2816]
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.094031
#
# Epoch 31
# -------------------------------
# loss: 0.050942  [    0/ 2816]
# loss: 0.290946  [  640/ 2816]
# loss: 0.069158  [ 1280/ 2816]
# loss: 0.034218  [ 1920/ 2816]
# loss: 0.071007  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.049917
#
# Epoch 32
# -------------------------------
# loss: 0.051660  [    0/ 2816]
# loss: 0.106019  [  640/ 2816]
# loss: 0.084695  [ 1280/ 2816]
# loss: 0.014666  [ 1920/ 2816]
# loss: 0.337860  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.033260
#
# Epoch 33
# -------------------------------
# loss: 0.038146  [    0/ 2816]
# loss: 0.034856  [  640/ 2816]
# loss: 0.021512  [ 1280/ 2816]
# loss: 0.052236  [ 1920/ 2816]
# loss: 0.006580  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.9%, Avg loss: 0.061040
#
# Epoch 34
# -------------------------------
# loss: 0.010492  [    0/ 2816]
# loss: 0.081568  [  640/ 2816]
# loss: 0.014648  [ 1280/ 2816]
# loss: 0.175230  [ 1920/ 2816]
# loss: 0.051841  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.032485
#
# Epoch 35
# -------------------------------
# loss: 0.102097  [    0/ 2816]
# loss: 0.012585  [  640/ 2816]
# loss: 0.015644  [ 1280/ 2816]
# loss: 0.031275  [ 1920/ 2816]
# loss: 0.181983  [ 2560/ 2816]
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.325239
#
# Epoch 36
# -------------------------------
# loss: 0.111131  [    0/ 2816]
# loss: 0.012564  [  640/ 2816]
# loss: 0.123476  [ 1280/ 2816]
# loss: 0.040499  [ 1920/ 2816]
# loss: 0.026878  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.047562
#
# Epoch 37
# -------------------------------
# loss: 0.018270  [    0/ 2816]
# loss: 0.102290  [  640/ 2816]
# loss: 0.052182  [ 1280/ 2816]
# loss: 0.051591  [ 1920/ 2816]
# loss: 0.053548  [ 2560/ 2816]
# Test Error:
#  Accuracy: 98.9%, Avg loss: 0.043119
#
# Epoch 38
# -------------------------------
# loss: 0.029491  [    0/ 2816]
# loss: 0.075241  [  640/ 2816]
# loss: 0.043114  [ 1280/ 2816]
# loss: 0.033826  [ 1920/ 2816]
# loss: 0.056836  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.5%, Avg loss: 0.021010
#
# Epoch 39
# -------------------------------
# loss: 0.028312  [    0/ 2816]
# loss: 0.029009  [  640/ 2816]
# loss: 0.007486  [ 1280/ 2816]
# loss: 0.008548  [ 1920/ 2816]
# loss: 0.036755  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.9%, Avg loss: 0.004632
#
# Epoch 40
# -------------------------------
# loss: 0.002902  [    0/ 2816]
# loss: 0.002799  [  640/ 2816]
# loss: 0.004379  [ 1280/ 2816]
# loss: 0.002128  [ 1920/ 2816]
# loss: 0.006873  [ 2560/ 2816]
# Test Error:
#  Accuracy: 99.7%, Avg loss: 0.010584
#
# Epoch 41
# -------------------------------
# loss: 0.003018  [    0/ 2816]
# loss: 0.008364  [  640/ 2816]
# loss: 0.004832  [ 1280/ 2816]
# loss: 0.003085  [ 1920/ 2816]
# loss: 0.001048  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.001670
#
# Epoch 42
# -------------------------------
# loss: 0.000921  [    0/ 2816]
# loss: 0.001799  [  640/ 2816]
# loss: 0.002300  [ 1280/ 2816]
# loss: 0.001529  [ 1920/ 2816]
# loss: 0.002194  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.001238
#
# Epoch 43
# -------------------------------
# loss: 0.000955  [    0/ 2816]
# loss: 0.001150  [  640/ 2816]
# loss: 0.002062  [ 1280/ 2816]
# loss: 0.000832  [ 1920/ 2816]
# loss: 0.000990  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.001085
#
# Epoch 44
# -------------------------------
# loss: 0.001178  [    0/ 2816]
# loss: 0.001163  [  640/ 2816]
# loss: 0.000726  [ 1280/ 2816]
# loss: 0.000914  [ 1920/ 2816]
# loss: 0.000911  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000999
#
# Epoch 45
# -------------------------------
# loss: 0.000754  [    0/ 2816]
# loss: 0.001219  [  640/ 2816]
# loss: 0.000872  [ 1280/ 2816]
# loss: 0.000740  [ 1920/ 2816]
# loss: 0.000944  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000918
#
# Epoch 46
# -------------------------------
# loss: 0.001168  [    0/ 2816]
# loss: 0.001197  [  640/ 2816]
# loss: 0.000703  [ 1280/ 2816]
# loss: 0.001517  [ 1920/ 2816]
# loss: 0.000729  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000852
#
# Epoch 47
# -------------------------------
# loss: 0.001119  [    0/ 2816]
# loss: 0.001017  [  640/ 2816]
# loss: 0.001374  [ 1280/ 2816]
# loss: 0.000539  [ 1920/ 2816]
# loss: 0.000817  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000750
#
# Epoch 49
# -------------------------------
# loss: 0.000604  [    0/ 2816]
# loss: 0.000779  [  640/ 2816]
# loss: 0.000523  [ 1280/ 2816]
# loss: 0.001069  [ 1920/ 2816]
# loss: 0.000960  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000714
#
# Epoch 50
# -------------------------------
# loss: 0.000548  [    0/ 2816]
# loss: 0.000871  [  640/ 2816]
# loss: 0.000524  [ 1280/ 2816]
# loss: 0.000583  [ 1920/ 2816]
# loss: 0.000503  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000671
#
# Epoch 51
# -------------------------------
# loss: 0.000727  [    0/ 2816]
# loss: 0.000756  [  640/ 2816]
# loss: 0.000631  [ 1280/ 2816]
# loss: 0.000518  [ 1920/ 2816]
# loss: 0.000484  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000638
#
# Epoch 52
# -------------------------------
# loss: 0.000470  [    0/ 2816]
# loss: 0.000900  [  640/ 2816]
# loss: 0.000594  [ 1280/ 2816]
# loss: 0.000656  [ 1920/ 2816]
# loss: 0.000747  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000607
#
# Epoch 53
# -------------------------------
# loss: 0.000816  [    0/ 2816]
# loss: 0.000762  [  640/ 2816]
# loss: 0.000705  [ 1280/ 2816]
# loss: 0.000605  [ 1920/ 2816]
# loss: 0.000689  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000580
#
# Epoch 54
# -------------------------------
# loss: 0.000687  [    0/ 2816]
# loss: 0.000553  [  640/ 2816]
# loss: 0.000390  [ 1280/ 2816]
# loss: 0.000634  [ 1920/ 2816]
# loss: 0.000320  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000554
#
# Epoch 55
# -------------------------------
# loss: 0.000469  [    0/ 2816]
# loss: 0.000394  [  640/ 2816]
# loss: 0.000864  [ 1280/ 2816]
# loss: 0.000625  [ 1920/ 2816]
# loss: 0.000441  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000532
#
# Epoch 56
# -------------------------------
# loss: 0.000602  [    0/ 2816]
# loss: 0.000344  [  640/ 2816]
# loss: 0.000472  [ 1280/ 2816]
# loss: 0.000552  [ 1920/ 2816]
# loss: 0.000668  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000508
#
# Epoch 57
# -------------------------------
# loss: 0.000397  [    0/ 2816]
# loss: 0.000419  [  640/ 2816]
# loss: 0.000591  [ 1280/ 2816]
# loss: 0.000414  [ 1920/ 2816]
# loss: 0.000191  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000489
#
# Epoch 58
# -------------------------------
# loss: 0.000326  [    0/ 2816]
# loss: 0.000547  [  640/ 2816]
# loss: 0.000435  [ 1280/ 2816]
# loss: 0.000346  [ 1920/ 2816]
# loss: 0.000635  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000470
#
# Epoch 59
# -------------------------------
# loss: 0.000436  [    0/ 2816]
# loss: 0.000524  [  640/ 2816]
# loss: 0.000460  [ 1280/ 2816]
# loss: 0.000395  [ 1920/ 2816]
# loss: 0.000599  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000453
#
# Epoch 60
# -------------------------------
# loss: 0.000303  [    0/ 2816]
# loss: 0.000441  [  640/ 2816]
# loss: 0.000329  [ 1280/ 2816]
# loss: 0.000478  [ 1920/ 2816]
# loss: 0.000509  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000435
#
# Epoch 61
# -------------------------------
# loss: 0.000588  [    0/ 2816]
# loss: 0.000319  [  640/ 2816]
# loss: 0.000389  [ 1280/ 2816]
# loss: 0.000391  [ 1920/ 2816]
# loss: 0.000554  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000420
#
# Epoch 62
# -------------------------------
# loss: 0.000344  [    0/ 2816]
# loss: 0.000662  [  640/ 2816]
# loss: 0.000530  [ 1280/ 2816]
# loss: 0.000322  [ 1920/ 2816]
# loss: 0.000276  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000405
#
# Epoch 63
# -------------------------------
# loss: 0.000532  [    0/ 2816]
# loss: 0.000439  [  640/ 2816]
# loss: 0.000332  [ 1280/ 2816]
# loss: 0.000303  [ 1920/ 2816]
# loss: 0.000422  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000391
#
# Epoch 64
# -------------------------------
# loss: 0.000432  [    0/ 2816]
# loss: 0.000530  [  640/ 2816]
# loss: 0.000395  [ 1280/ 2816]
# loss: 0.000458  [ 1920/ 2816]
# loss: 0.000369  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000379
#
# Epoch 65
# -------------------------------
# loss: 0.000356  [    0/ 2816]
# loss: 0.000422  [  640/ 2816]
# loss: 0.000306  [ 1280/ 2816]
# loss: 0.000309  [ 1920/ 2816]
# loss: 0.000374  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000366
#
# Epoch 66
# -------------------------------
# loss: 0.000241  [    0/ 2816]
# loss: 0.000345  [  640/ 2816]
# loss: 0.000512  [ 1280/ 2816]
# loss: 0.000338  [ 1920/ 2816]
# loss: 0.000436  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000354
#
# Epoch 67
# -------------------------------
# loss: 0.000290  [    0/ 2816]
# loss: 0.000370  [  640/ 2816]
# loss: 0.000379  [ 1280/ 2816]
# loss: 0.000284  [ 1920/ 2816]
# loss: 0.000299  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000342
#
# Epoch 68
# -------------------------------
# loss: 0.000379  [    0/ 2816]
# loss: 0.000284  [  640/ 2816]
# loss: 0.000250  [ 1280/ 2816]
# loss: 0.000400  [ 1920/ 2816]
# loss: 0.000553  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000331
#
# Epoch 69
# -------------------------------
# loss: 0.000321  [    0/ 2816]
# loss: 0.000292  [  640/ 2816]
# loss: 0.000361  [ 1280/ 2816]
# loss: 0.000233  [ 1920/ 2816]
# loss: 0.000320  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000321
#
# Epoch 70
# -------------------------------
# loss: 0.000370  [    0/ 2816]
# loss: 0.000343  [  640/ 2816]
# loss: 0.000326  [ 1280/ 2816]
# loss: 0.000408  [ 1920/ 2816]
# loss: 0.000286  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000312
#
# Epoch 71
# -------------------------------
# loss: 0.000325  [    0/ 2816]
# loss: 0.000401  [  640/ 2816]
# loss: 0.000175  [ 1280/ 2816]
# loss: 0.000412  [ 1920/ 2816]
# loss: 0.000277  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000302
#
# Epoch 72
# -------------------------------
# loss: 0.000314  [    0/ 2816]
# loss: 0.000315  [  640/ 2816]
# loss: 0.000279  [ 1280/ 2816]
# loss: 0.000412  [ 1920/ 2816]
# loss: 0.000263  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000293
#
# Epoch 73
# -------------------------------
# loss: 0.000196  [    0/ 2816]
# loss: 0.000227  [  640/ 2816]
# loss: 0.000301  [ 1280/ 2816]
# loss: 0.000207  [ 1920/ 2816]
# loss: 0.000267  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000285
#
# Epoch 74
# -------------------------------
# loss: 0.000291  [    0/ 2816]
# loss: 0.000303  [  640/ 2816]
# loss: 0.000249  [ 1280/ 2816]
# loss: 0.000226  [ 1920/ 2816]
# loss: 0.000198  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000276
#
# Epoch 75
# -------------------------------
# loss: 0.000318  [    0/ 2816]
# loss: 0.000228  [  640/ 2816]
# loss: 0.000222  [ 1280/ 2816]
# loss: 0.000279  [ 1920/ 2816]
# loss: 0.000292  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000268
#
# Epoch 76
# -------------------------------
# loss: 0.000287  [    0/ 2816]
# loss: 0.000226  [  640/ 2816]
# loss: 0.000297  [ 1280/ 2816]
# loss: 0.000237  [ 1920/ 2816]
# loss: 0.000271  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000261
#
# Epoch 77
# -------------------------------
# loss: 0.000243  [    0/ 2816]
# loss: 0.000125  [  640/ 2816]
# loss: 0.000310  [ 1280/ 2816]
# loss: 0.000164  [ 1920/ 2816]
# loss: 0.000260  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000253
#
# Epoch 78
# -------------------------------
# loss: 0.000168  [    0/ 2816]
# loss: 0.000233  [  640/ 2816]
# loss: 0.000228  [ 1280/ 2816]
# loss: 0.000307  [ 1920/ 2816]
# loss: 0.000293  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000246
#
# Epoch 79
# -------------------------------
# loss: 0.000203  [    0/ 2816]
# loss: 0.000239  [  640/ 2816]
# loss: 0.000278  [ 1280/ 2816]
# loss: 0.000202  [ 1920/ 2816]
# loss: 0.000239  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000241
#
# Epoch 80
# -------------------------------
# loss: 0.000334  [    0/ 2816]
# loss: 0.000296  [  640/ 2816]
# loss: 0.000276  [ 1280/ 2816]
# loss: 0.000319  [ 1920/ 2816]
# loss: 0.000196  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000233
#
# Epoch 81
# -------------------------------
# loss: 0.000208  [    0/ 2816]
# loss: 0.000271  [  640/ 2816]
# loss: 0.000193  [ 1280/ 2816]
# loss: 0.000201  [ 1920/ 2816]
# loss: 0.000288  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000227
#
# Epoch 82
# -------------------------------
# loss: 0.000211  [    0/ 2816]
# loss: 0.000243  [  640/ 2816]
# loss: 0.000189  [ 1280/ 2816]
# loss: 0.000232  [ 1920/ 2816]
# loss: 0.000192  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000221
#
# Epoch 83
# -------------------------------
# loss: 0.000276  [    0/ 2816]
# loss: 0.000128  [  640/ 2816]
# loss: 0.000267  [ 1280/ 2816]
# loss: 0.000264  [ 1920/ 2816]
# loss: 0.000154  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000215
#
# Epoch 84
# -------------------------------
# loss: 0.000165  [    0/ 2816]
# loss: 0.000317  [  640/ 2816]
# loss: 0.000183  [ 1280/ 2816]
# loss: 0.000162  [ 1920/ 2816]
# loss: 0.000238  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000209
#
# Epoch 85
# -------------------------------
# loss: 0.000181  [    0/ 2816]
# loss: 0.000360  [  640/ 2816]
# loss: 0.000159  [ 1280/ 2816]
# loss: 0.000239  [ 1920/ 2816]
# loss: 0.000217  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000204
#
# Epoch 86
# -------------------------------
# loss: 0.000310  [    0/ 2816]
# loss: 0.000158  [  640/ 2816]
# loss: 0.000171  [ 1280/ 2816]
# loss: 0.000157  [ 1920/ 2816]
# loss: 0.000248  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000198
#
# Epoch 87
# -------------------------------
# loss: 0.000182  [    0/ 2816]
# loss: 0.000230  [  640/ 2816]
# loss: 0.000159  [ 1280/ 2816]
# loss: 0.000214  [ 1920/ 2816]
# loss: 0.000143  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000193
#
# Epoch 88
# -------------------------------
# loss: 0.000159  [    0/ 2816]
# loss: 0.000121  [  640/ 2816]
# loss: 0.000202  [ 1280/ 2816]
# loss: 0.000217  [ 1920/ 2816]
# loss: 0.000204  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000189
#
# Epoch 89
# -------------------------------
# loss: 0.000183  [    0/ 2816]
# loss: 0.000205  [  640/ 2816]
# loss: 0.000157  [ 1280/ 2816]
# loss: 0.000203  [ 1920/ 2816]
# loss: 0.000191  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000183
#
# Epoch 90
# -------------------------------
# loss: 0.000219  [    0/ 2816]
# loss: 0.000180  [  640/ 2816]
# loss: 0.000284  [ 1280/ 2816]
# loss: 0.000217  [ 1920/ 2816]
# loss: 0.000184  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000179
#
# Epoch 91
# -------------------------------
# loss: 0.000149  [    0/ 2816]
# loss: 0.000172  [  640/ 2816]
# loss: 0.000130  [ 1280/ 2816]
# loss: 0.000165  [ 1920/ 2816]
# loss: 0.000241  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000174
#
# Epoch 92
# -------------------------------
# loss: 0.000252  [    0/ 2816]
# loss: 0.000136  [  640/ 2816]
# loss: 0.000292  [ 1280/ 2816]
# loss: 0.000234  [ 1920/ 2816]
# loss: 0.000175  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000170
#
# Epoch 93
# -------------------------------
# loss: 0.000154  [    0/ 2816]
# loss: 0.000170  [  640/ 2816]
# loss: 0.000164  [ 1280/ 2816]
# loss: 0.000209  [ 1920/ 2816]
# loss: 0.000117  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000166
#
# Epoch 94
# -------------------------------
# loss: 0.000152  [    0/ 2816]
# loss: 0.000169  [  640/ 2816]
# loss: 0.000216  [ 1280/ 2816]
# loss: 0.000189  [ 1920/ 2816]
# loss: 0.000155  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000161
#
# Epoch 95
# -------------------------------
# loss: 0.000160  [    0/ 2816]
# loss: 0.000134  [  640/ 2816]
# loss: 0.000194  [ 1280/ 2816]
# loss: 0.000110  [ 1920/ 2816]
# loss: 0.000115  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000157
#
# Epoch 96
# -------------------------------
# loss: 0.000138  [    0/ 2816]
# loss: 0.000136  [  640/ 2816]
# loss: 0.000263  [ 1280/ 2816]
# loss: 0.000119  [ 1920/ 2816]
# loss: 0.000141  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000153
#
# Epoch 97
# -------------------------------
# loss: 0.000195  [    0/ 2816]
# loss: 0.000116  [  640/ 2816]
# loss: 0.000110  [ 1280/ 2816]
# loss: 0.000103  [ 1920/ 2816]
# loss: 0.000181  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000150
#
# Epoch 98
# -------------------------------
# loss: 0.000172  [    0/ 2816]
# loss: 0.000184  [  640/ 2816]
# loss: 0.000094  [ 1280/ 2816]
# loss: 0.000137  [ 1920/ 2816]
# loss: 0.000132  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000146
#
# Epoch 99
# -------------------------------
# loss: 0.000148  [    0/ 2816]
# loss: 0.000120  [  640/ 2816]
# loss: 0.000125  [ 1280/ 2816]
# loss: 0.000117  [ 1920/ 2816]
# loss: 0.000144  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000142
#
# Epoch 100
# -------------------------------
# loss: 0.000152  [    0/ 2816]
# loss: 0.000114  [  640/ 2816]
# loss: 0.000159  [ 1280/ 2816]
# loss: 0.000236  [ 1920/ 2816]
# loss: 0.000111  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000139
#
# Epoch 101
# -------------------------------
# loss: 0.000137  [    0/ 2816]
# loss: 0.000160  [  640/ 2816]
# loss: 0.000136  [ 1280/ 2816]
# loss: 0.000148  [ 1920/ 2816]
# loss: 0.000135  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000135
#
# Epoch 102
# -------------------------------
# loss: 0.000160  [    0/ 2816]
# loss: 0.000109  [  640/ 2816]
# loss: 0.000106  [ 1280/ 2816]
# loss: 0.000145  [ 1920/ 2816]
# loss: 0.000135  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000132
#
# Epoch 103
# -------------------------------
# loss: 0.000108  [    0/ 2816]
# loss: 0.000141  [  640/ 2816]
# loss: 0.000171  [ 1280/ 2816]
# loss: 0.000145  [ 1920/ 2816]
# loss: 0.000175  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000128
#
# Epoch 104
# -------------------------------
# loss: 0.000096  [    0/ 2816]
# loss: 0.000092  [  640/ 2816]
# loss: 0.000131  [ 1280/ 2816]
# loss: 0.000118  [ 1920/ 2816]
# loss: 0.000177  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000126
#
# Epoch 105
# -------------------------------
# loss: 0.000129  [    0/ 2816]
# loss: 0.000124  [  640/ 2816]
# loss: 0.000097  [ 1280/ 2816]
# loss: 0.000129  [ 1920/ 2816]
# loss: 0.000096  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000123
#
# Epoch 106
# -------------------------------
# loss: 0.000133  [    0/ 2816]
# loss: 0.000093  [  640/ 2816]
# loss: 0.000120  [ 1280/ 2816]
# loss: 0.000126  [ 1920/ 2816]
# loss: 0.000101  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000119
#
# Epoch 107
# -------------------------------
# loss: 0.000104  [    0/ 2816]
# loss: 0.000111  [  640/ 2816]
# loss: 0.000084  [ 1280/ 2816]
# loss: 0.000131  [ 1920/ 2816]
# loss: 0.000151  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000116
#
# Epoch 108
# -------------------------------
# loss: 0.000120  [    0/ 2816]
# loss: 0.000108  [  640/ 2816]
# loss: 0.000116  [ 1280/ 2816]
# loss: 0.000125  [ 1920/ 2816]
# loss: 0.000097  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000114
#
# Epoch 109
# -------------------------------
# loss: 0.000060  [    0/ 2816]
# loss: 0.000073  [  640/ 2816]
# loss: 0.000215  [ 1280/ 2816]
# loss: 0.000077  [ 1920/ 2816]
# loss: 0.000110  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000111
#
# Epoch 110
# -------------------------------
# loss: 0.000161  [    0/ 2816]
# loss: 0.000128  [  640/ 2816]
# loss: 0.000115  [ 1280/ 2816]
# loss: 0.000145  [ 1920/ 2816]
# loss: 0.000141  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000108
#
# Epoch 111
# -------------------------------
# loss: 0.000178  [    0/ 2816]
# loss: 0.000063  [  640/ 2816]
# loss: 0.000095  [ 1280/ 2816]
# loss: 0.000117  [ 1920/ 2816]
# loss: 0.000124  [ 2560/ 2816]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000106
#
# Epoch 112
# -------------------------------
# loss: 0.000075  [    0/ 2816]

# %%
fig = plt.figure(figsize=(10, 5.5))
plt.plot(train_loss, c="b", label="train")
plt.plot(val_loss, c="y", label="valid")
plt.legend()
plt.title("train-val loss")
plt.show()

# %%
test(test_dataloader, model_vnn, loss_fn)

# %% [markdown]
# ##### some results
#
# n_epochs=30,   w, h = 256, 128: Test : Accuracy: 46.1%, Avg loss: 3.086656
#
# n_epochs=30,   w, h = 224, 224: Test : Accuracy: 45.6%, Avg loss: 2.969669
#
# n_epochs=150,  w, h = 224, 224: Test :
